# %%
import spotipy
import json 
from spotipy.oauth2 import SpotifyClientCredentials
from IPython.display import IFrame
import pandas as pd

# %%
c_id = "6393a3f65ec8488aacecb43184202152"
c_se = "22e4999d9d174b46a25eed3c2875bc45"

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=c_id, client_secret=c_se))

# %%
track_id = "6A9mKXlFRPMPem6ygQSt7z"

# %%
playlist = sp.user_playlist_tracks("spotify", "4ONdTgODsdMvCrJ9ANld3Y",market="GB")

# %%
# Getting details of playlist (by playlist id)

def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
playlist = get_playlist_tracks("spotify", "37i9dQZF1DX8FwnYE6PRvL")

# %%
# Function for everything

def songs_df(playlist):
    ids = []
    titles = []
    artists = []
    features = []
    
     
    for i in range(len(playlist)):
        ids.append(playlist[i]["track"]["id"]) #getting track ids
    
    for i in ids:
        titles.append((sp.track(i)["name"])) # getting titles by ids
   
    for i in ids: 
        multiple_artists = []
        for j in sp.track(i)["artists"]:
            multiple_artists.append(j["name"])
        artists.append(", ".join(multiple_artists)) # getting artists by ids
        
    
    for i in ids:
        features.append(sp.audio_features(i)[0]) # getting features by ids
        
    playlist_df = pd.DataFrame({"artist": artists, "title":titles, "id":ids})
    features_df = pd.DataFrame.from_dict(features)
    final_df = pd.merge(playlist_df, features_df, on="id")
    final_df = final_df.drop_duplicates()
    final_df.reset_index(drop=True)
    final_df.to_csv('songs_df.csv', mode='a', header=False, index=False)    

songs_df(playlist)

# %%
aa = pd.read_csv("songs_df.csv")

# %%
aa.tail(60)
# Out:
#                                           artist  \
# 324                                         MiMS
# 325                                       N.W.A.
# 326                                          Nas
# 327                                        Nelly
# 328              Blackstreet, Dr. Dre, Queen Pen
# 329                                         2Pac
# 330                                        Drake
# 331                                       N.W.A.
# 332          Dem Franchize Boyz, Peanut, Charlay
# 333                                      50 Cent
# 334                             Ja Rule, Ashanti
# 335                                         T.I.
# 336                      Trey Songz, Nicki Minaj
# 337                                    Rick Ross
# 338                Snoop Dogg, Pharrell Williams
# 339                                 Busta Rhymes
# 340                         The Notorious B.I.G.
# 341                            Jeezy, Kanye West
# ...

# %%
aa.drop_duplicates(inplace=True)

# %%
s.ds,.dsaadas.

# %% [markdown]
# # Getting ids of the tracks in the playlist
# ids = []
# def get_id(playlist):
#     try:
#         for i in range(len(playlist)):
#             ids.append(playlist[i]["track"]["id"])
#     except:
#         if playlist.strip() == "":
#             continue
#
# get_id(playlist)
# len(ids)

# %%
# Getting details of playlist (by playlist id)

def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks
playlist = get_playlist_tracks("spotify", "37i9dQZF1DX5uokaTN4FTR")

# %%
#Getting ids
ids = []
for i in range(len(playlist)):
            ids.append(playlist[i]["track"]["id"])
len(ids)
# Out:
# 50

# %%
# Getting artists by ids
artists = []
for i in ids:
# Out:
# '3NeSlNBRvB4BMrxhA88Zke'

# %%
sp.track("3sa06xVNmLLYIxdNNmVQN8")["artists"][0]["name"]
# Out:
# 'Jax Jones'

# %%
len(ids)
# Out:
# 50

# %%
artists = []
for i in ids: 
    multiple_artists = []
    for j in sp.track(i)["artists"]:
        multiple_artists.append(j["name"])
    artists.append(", ".join(multiple_artists))

# %%
len(artists)
# Out:
# 50

# %%
artists
# Out:
# ['Wilkinson, Becky Hill',
#  'Jax Jones, MNEK',
#  'Joel Corry, Da Hool',
#  'D.O.D, Carla Monroe',
#  'Belters Only, Jazzy',
#  'Seamus D',
#  'Charli XCX, Rina Sawayama',
#  'Luude, Colin Hay',
#  'Sigala',
#  'piri, Tommy Villiers',
#  'Shane Codd',
#  'Aluna, Diplo, Durante, AlunaGeorge',
#  'TS7',
#  'TeeDee',
#  'Bru-C, Wilkinson',
#  'Silky, TeeDee',
#  'Disclosure, Zedd',
#  'Years & Years, Galantis',
#  'Vintage Culture, James Hype',
#  'Fred again.., Romy, HAAi',
#  'Tom Zanetti, Siobhan',
#  'Lost Frequencies, Calum Scott',
#  'Wilkinson, Issey Cross',
#  'ACRAZE, Cherish',
#  'Love Regenerator, Riva Starr, Calvin Harris, Sananda Maitreya',
#  'Bad Boy Chiller Crew',
#  'Topic, Robin Schulz, Nico Santos, Paul van Dyk',
#  'MEDUZA, Hozier',
#  'Emily Nash',
#  'Jethro Heston, Max Marshall',
#  'Anz, George Riley',
#  'System.Inc, Jax Jones, Stefflon Don',
#  'Alesso, Katy Perry',
#  'Vintage Culture, Sonny Fodera, SHELLS',
#  'Ben Nicky, Distorted Dreams',
#  'New Hype',
# ...

# %%
for i in range(len(ids)):
    for j in range(len(sp.track(ids[i]))["artists"]):
        print(sp.track("3sa06xVNmLLYIxdNNmVQN8")["artists"][j]["name"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18100/2083126207.py in <module>
#       1 for i in range(len(ids)):
# ----> 2     for j in range(len(sp.track(ids[i]))["artists"]):
#       3         print(sp.track("3sa06xVNmLLYIxdNNmVQN8")["artists"][j]["name"])
#
# TypeError: 'int' object is not subscriptable

# %%
names=[]
for i in ids:
    print(sp.track("3sa06xVNmLLYIxdNNmVQN8", market=None)["artists"][i]["name"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18100/1730609849.py in <module>
#       1 names=[]
#       2 for i in ids:
# ----> 3     print(sp.track("3sa06xVNmLLYIxdNNmVQN8", market=None)["artists"][i]["name"])
#
# TypeError: list indices must be integers or slices, not str

# %%
for i in range(len((sp.track("3sa06xVNmLLYIxdNNmVQN8", market=None)["artists"][1]["name"])):
    print(sp.track("3sa06xVNmLLYIxdNNmVQN8", market=None)["artists"][i]["name"])
# Out:
#   File "C:\Users\atycn\AppData\Local\Temp/ipykernel_18100/3457502497.py", line 1
#     for i in range(len((sp.track("3sa06xVNmLLYIxdNNmVQN8", market=None)["artists"][1]["name"])):
#                                                                                                ^
# SyntaxError: invalid syntax

# %%
# Getting titles by ids
titles = []
for i in ids:
    titles.append((sp.track(i)["name"]))
len(titles)
# Out:
# 80

# %%
# Getting features by ids
features = []
for i in ids:
    features.append(sp.audio_features(i)[0])
len(features)
# Out:
# 80

# %%
# Creating df with artists, titles and ids
playlist_df = pd.DataFrame({"artist": artists, "title":titles, "id":ids})
playlist_df
# Out:
#            artist                                  title  \
# 0   Guns N' Roses                          Paradise City
# 1     The Strokes                              Last Nite
# 2           AC/DC            You Shook Me All Night Long
# 3    Led Zeppelin       Whole Lotta Love - 1990 Remaster
# 4         Nirvana                Smells Like Teen Spirit
# ..            ...                                    ...
# 75      The Kinks           You Really Got Me - Mono Mix
# 76    Mötley Crüe                    Girls, Girls, Girls
# 77        Blondie                                Call Me
# 78         Sum 41                            In Too Deep
# 79          Oasis  Don't Look Back In Anger - Remastered
#
#                         id
# 0   3YBZIN3rekqsKxbJc9FZko
# 1   7kzKAuUzOITUauHAhoMoxA
# 2   6yl8Es1tCYD9WdSkeVLFw4
# 3   0hCB0YR03f6AmQaHbwWDe8
# 4   4CeeEOM32jQcH3eN9Q2dGj
# ..                     ...
# 75  29SyMC0plk6qw8NMF7lfRL
# 76  549Go7a66CX6k523uK9kUv
# ...

# %%
# Creating df with features and ids
features_df = pd.DataFrame.from_dict(features)
features_df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.273   0.952   11    -8.762     1       0.0843      0.016900
# 1          0.624   0.910    0    -5.703     1       0.0297      0.028500
# 2          0.529   0.768    7    -5.510     1       0.0566      0.002240
# 3          0.412   0.902    9   -11.600     1       0.4050      0.048400
# 4          0.502   0.912    1    -4.556     1       0.0564      0.000025
# ..           ...     ...  ...       ...   ...          ...           ...
# 75         0.573   0.939    8    -6.441     1       0.0808      0.493000
# 76         0.599   0.931    7    -4.653     1       0.0735      0.030200
# 77         0.560   0.825    2    -6.711     0       0.0347      0.000785
# 78         0.568   0.844    9    -5.875     1       0.0505      0.000189
# 79         0.328   0.936    0    -3.254     1       0.0628      0.066500
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
# Merging by id
final_df = pd.merge(playlist_df, features_df, on="id")

# %%
# One song was twice in the playlist (one id was repeated) so dropping duplicates
final_df = final_df.drop_duplicates()

# %%
# Reseting index after dropping duplicates and dropping old index so it's not added as a column
final_df.reset_index(drop=True)
# Out:
#            artist                                  title  \
# 0   Guns N' Roses                          Paradise City
# 1     The Strokes                              Last Nite
# 2           AC/DC            You Shook Me All Night Long
# 3    Led Zeppelin       Whole Lotta Love - 1990 Remaster
# 4         Nirvana                Smells Like Teen Spirit
# ..            ...                                    ...
# 75      The Kinks           You Really Got Me - Mono Mix
# 76    Mötley Crüe                    Girls, Girls, Girls
# 77        Blondie                                Call Me
# 78         Sum 41                            In Too Deep
# 79          Oasis  Don't Look Back In Anger - Remastered
#
#                         id  danceability  energy  key  loudness  mode  \
# 0   3YBZIN3rekqsKxbJc9FZko         0.273   0.952   11    -8.762     1
# 1   7kzKAuUzOITUauHAhoMoxA         0.624   0.910    0    -5.703     1
# ...

# %%
final_df.to_csv("songs_df.csv")

# %%
# df.to_csv('songs_df.csv', mode='a', index=False, header=False)

# %% [markdown]
# #Features by titles
#
# features=[]
# for index in range(len(titles)):
#     features.append(sp.audio_features(sp.search(q=titles[index],market="GB")["tracks"]["items"][0]["uri"])[0])

# %% [markdown]
# #Titles and ids from playlist
# titles=[]
# ids=[]
# for i in range(len(playlist)):
#     titles.append(playlist[i]['track']['name'])
#     ids.append(playlist[i]['track']['id'])

# %% [markdown]
# #Checking for duplicates in the list of ids: there is one duplicate; it explains why the final df is too long
# #and drop_duplicates is needed
# set([x for x in ids if ids.count(x) > 1])

# %%
IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
   
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
